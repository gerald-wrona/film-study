# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\wrona'

# %%
import pandas as pd
films = pd.read_csv('films.csv')

# %%
films
# Out:
#                      Title            Writer*           Director  \
# 0      Inglorious Basterds  Quentin Tarantino  Quentin Tarantino
# 1        The Hateful Eight  Quentin Tarantino  Quentin Tarantino
# 2         Django Unchained  Quentin Tarantino  Quentin Tarantino
# 3                In Bruges    Martin McDonagh    Martin McDonagh
# 4        Seven Psychopaths    Martin McDonagh    Martin McDonagh
# ..                     ...                ...                ...
# 80  Grave of the Fireflies      Isao Takahata     Akiyuki Nosaka
# 81                    Haru  Yoshimitsu Morita  Yoshimitsu Morita
# 82   Right Now, Wrong Then      Hong Sang-soo      Hong Sang-soo
# 83             Six Shooter    Martin McDonagh    Martin McDonagh
# 84     The Hidden Fortress  Shinobu Hashimoto     Akira Kurosawa
#
#     Is Adaptation  Language
# 0             0.0   english
# 1             0.0   english
# 2             0.0   english
# 3             0.0   english
# 4             0.0   english
# ...

# %%
written = films.groupby(['Writer*']).size().reset_index(name='total_written')

# %%
films = films.merge(written, on='Writer*', how="left")

# %%
directed = films.groupby(['Director']).size().reset_index(name='total_directed')
films = films.merge(directed, on='Director', how="left")

# %%
languages = films.groupby(['Language']).size().reset_index(name='total_language')
films = films.merge(languages, on='Language', how="left")

# %%
films['Writer*'].value_counts()
writer_chart = films.drop(films[films.total_directed < 2].index)
writer_chart['Writer*'].hist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-ed303e0682a0> in <module>
#       2 writer_chart = films.drop(films[films.total_directed < 2].index)
#       3 writer_chart['Writer*'].hist()
# ----> 4 plt.xticks(rotation=45)
#
# NameError: name 'plt' is not defined

# %%
films.groupby(['Writer*']).size().reset_index(name='total_written').sort_values(by='total_written', ascending=False)
# Out:
#                               Writer*  total_written
# 38                    Martin McDonagh              5
# 19                     Hayao Miyazaki              4
# 46                  Quentin Tarantino              3
# 24                      Isao Takahata              3
# 50          Ron Clements, John Musker              2
# ..                                ...            ...
# 30              John Michael McDonagh              1
# 31  Jonathan Nolan, Christopher Nolan              1
# 32                   Josephine Decker              1
# 33                         Jymn Magon              1
# 67                        Zhangke Jia              1
#
# [68 rows x 2 columns]

# %%
films.groupby(['Director']).size().reset_index(name='total_directed').sort_values(by='total_directed', ascending=False)
# Out:
#                                     Director  total_directed
# 14                            Hayao Miyazaki               6
# 33                           Martin McDonagh               5
# 1                             Akira Kurosawa               3
# 40                         Quentin Tarantino               3
# 6                                  Brad Bird               3
# 46                               Satoshi Kon               3
# 16                             Isao Takahata               3
# 12               Dean DeBlois, Chris Sanders               2
# 36                              Miranda July               2
# 38                            Park Chan-wook               2
# 15                             Hong Sang-soo               2
# 17                                Jared Hess               2
# 10                             Coen Brothers               2
# 54                              Wong Kar-Wai               2
# ...
